# %% [markdown]
# ### **Contenido próximamente disponible. El recurso se actualizará automáticamente durante el semestre.**

# %% [markdown]
# ![progmatematica(color) mediano.png](data:image/png;base64,...)
